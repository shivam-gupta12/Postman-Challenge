# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/damodargupta/Desktop/postman challenge/Postman-Challenge/Campus Ambassador Referral Tracker.xlsx")

# %%
df
# Out:
#                       College / University / Institution  \
# 0      Datta Meghe Institute of Higher Education and ...
# 1                                  Kanshuso083@gmail.com
# 2      J.C Bose University of Science and technology,...
# 3                           aayushijain.jain23@gmail.com
# 4                                 Banasthali University
# ...                                                  ...
# 26367                                                NaN
# 26368                                                NaN
# 26369                                                NaN
# 26370                                                NaN
# 26371                                                NaN
#
#                       Email address             Name Referral Code  \
# 0            kambleaahash@gmail.com   Aahash Kamble       aaha-027
# 1                               NaN  Aakanksha Dubey      aaka-243
# 2            aakritimt562@gmail.com  Aakriti Mittal       aakr-191
# ...

# %%
df.drop(columns=["Referral Responses from Google Form", "College / University / Institution" , "Email address", "Referrals Count" ], inplace=True)

# %%
df
# Out:
#                   Name Referral Code
# 0       Aahash Kamble       aaha-027
# 1      Aakanksha Dubey      aaka-243
# 2      Aakriti Mittal       aakr-191
# 3         Aayushi Jain      aayu-280
# 4        Aayushi Jain       aayu-048
# ...                ...           ...
# 26367              NaN           NaN
# 26368              NaN           NaN
# 26369              NaN           NaN
# 26370              NaN           NaN
# 26371              NaN           NaN
#
# [26372 rows x 2 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                  Name Referral Code
# 0      Aahash Kamble       aaha-027
# 1     Aakanksha Dubey      aaka-243
# 2     Aakriti Mittal       aakr-191
# 3        Aayushi Jain      aayu-280
# 4       Aayushi Jain       aayu-048
# ..                ...           ...
# 318    Vinisha Dsouza      vini-260
# 319     Vishal Patel       vish-121
# 320     Vishal Rawat       vish-054
# 321      Vivek Kumar       vive-185
# 322  Vyuhita Gunupudi      vyuh-314
#
# [323 rows x 2 columns]

# %%
df.to_csv("name-referral-data.csv")
